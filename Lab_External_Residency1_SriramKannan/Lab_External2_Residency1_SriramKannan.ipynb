# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd;
iris= pd.read_csv(r'C:\Users\sriram.kannan\Desktop\PGP-AIML\Residency_1_Lab_External\Iris.csv', delimiter=",")
print (iris);
## reading the file delimited by comma
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                     5.1                  3.5                   1.4
# 1                     4.9                  3.0                   1.4
# 2                     4.7                  3.2                   1.3
# 3                     4.6                  3.1                   1.5
# 4                     5.0                  3.6                   1.4
# 5                     5.4                  3.9                   1.7
# 6                     4.6                  3.4                   1.4
# 7                     5.0                  3.4                   1.5
# 8                     4.4                  2.9                   1.4
# 9                     4.9                  3.1                   1.5
# 10                    5.4                  3.7                   1.5
# 11                    4.8                  3.4                   1.6
# 12                    4.8                  3.0                   1.4
# ...

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
a=iris.dtypes; print(a);
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
top= iris.head(10);## top 10
bottom=iris.tail(10); ## bottom 10
print(top);
print(bottom);
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa
# ...

# %% [markdown]
# ### Find the shape of the dataset

# %%
shape=iris.shape; print(shape);
# Out:
# (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
iris.iloc[:,0]=iris.index; ## setting the first column as index
print (iris); ## prints with the first column as index values
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                       0                  3.5                   1.4
# 1                       1                  3.0                   1.4
# 2                       2                  3.2                   1.3
# 3                       3                  3.1                   1.5
# 4                       4                  3.6                   1.4
# 5                       5                  3.9                   1.7
# 6                       6                  3.4                   1.4
# 7                       7                  3.4                   1.5
# 8                       8                  2.9                   1.4
# 9                       9                  3.1                   1.5
# 10                     10                  3.7                   1.5
# 11                     11                  3.4                   1.6
# 12                     12                  3.0                   1.4
# ...

# %% [markdown]
# ### Use Iloc function to print all the rows of the 3rd column

# %%
a=iris.iloc[:,2]
print(a); ## all rows of the third column
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.7
# 121    4.9
# 122    6.7
# 123    4.9
# 124    5.7
# 125    6.0
# 126    4.8
# 127    4.9
# 128    5.6
# 129    5.8
# 130    6.1
# 131    6.4
# 132    5.6
# 133    5.1
# 134    5.6
# 135    6.1
# 136    5.6
# 137    5.5
# 138    4.8
# 139    5.4
# 140    5.6
# 141    5.1
# 142    5.1
# 143    5.9
# 144    5.7
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: Petal length (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
a= iris.iloc[:10,0:2];
print(a); ## prints first 10 lines of Sepal length and Sepal width
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                     0                  3.5
# 1                     1                  3.0
# 2                     2                  3.2
# 3                     3                  3.1
# 4                     4                  3.6
# 5                     5                  3.9
# 6                     6                  3.4
# 7                     7                  3.4
# 8                     8                  2.9
# 9                     9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
a=iris.loc[iris['Class']=='Iris-setosa']; 
print(a); ## prints rows having "Iris-setosa" as Class name
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                      0                  3.5                   1.4
# 1                      1                  3.0                   1.4
# 2                      2                  3.2                   1.3
# 3                      3                  3.1                   1.5
# 4                      4                  3.6                   1.4
# 5                      5                  3.9                   1.7
# 6                      6                  3.4                   1.4
# 7                      7                  3.4                   1.5
# 8                      8                  2.9                   1.4
# 9                      9                  3.1                   1.5
# 10                    10                  3.7                   1.5
# 11                    11                  3.4                   1.6
# 12                    12                  3.0                   1.4
# ...

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra']= iris['Sepal Length (in cm)']* iris['Sepal Width in (cm)'];

print (iris); ##Adds SepalExtra as a new column
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 109                   7.2                  3.6                   6.1
# 144                   6.7                  3.3                   5.7
# 100                   6.3                  3.3                   6.0
# 114                   5.8                  2.8                   5.1
# 140                   6.7                  3.1                   5.6
# 136                   6.3                  3.4                   5.6
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# ...

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
## Mean and Variance for Sepal Width in (cm)
m1=iris['Sepal Width in (cm)'].mean(); v1=iris['Sepal Width in (cm)'].var(); 
print(m1); print(v1);

## Mean and Variance for Sepal Length in (cm)
m2=iris['Sepal Length (in cm)'].mean(); v2=iris['Sepal Length (in cm)'].var(); 
print(m2); print(v2);

## Mean and Variance for Petal length (in cm)
m3=iris['Petal length (in cm)'].mean(); v3=iris['Petal length (in cm)'].var(); 
print(m3); print(v3);

## Mean and Variance for Petal width (in cm)
m4=iris['Petal width (in cm)'].mean(); v4=iris['Petal width (in cm)'].var(); 
print(m4); print(v4);

## Mean and Variance for SepalExtra
m5=iris['SepalExtra'].mean(); v5=iris['SepalExtra'].var(); 
print(m5); print(v5);
# Out:
# 3.0540000000000007
# 0.18800402684563763
# 5.843333333333335
# 0.6856935123042505
# 3.7586666666666693
# 3.1131794183445156
# 1.1986666666666672
# 0.5824143176733784
# 17.806533333333338
# 11.34808991498881

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def two_num(a,b):
    print ("First number is", a);
    print ("Second number is", b);
    
i1=iris.iloc[4,]; ## to get the fifth row
sep_length=i1['Sepal Length (in cm)']; sep_width=i1['Sepal Width in (cm)']; ## to get the Sepal Length and Sepal width of the 5th row

output=two_num(sep_length, sep_width); ## prints the Sepal Length and Sepal Width using the function
# Out:
# First number is 5.0
# Second number is 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
## Range of Sepal Width in (cm)
m1=iris['Sepal Width in (cm)'].max(); v1=iris['Sepal Width in (cm)'].min(); 
r1=m1-v1;
print(r1); ## prints the range of Sepal Width

## Range of Sepal Length in (cm)
m2=iris['Sepal Length (in cm)'].max(); v2=iris['Sepal Length (in cm)'].min(); 
r2=m2-v2;
print(r2); ## prints the range of Sepal Length

## Range of Petal length (in cm)
m3=iris['Petal length (in cm)'].max(); v3=iris['Petal length (in cm)'].min(); 
r3=m3-v3;
print(r3); ## prints the range of Petal Length

## Range of Petal width (in cm)
m4=iris['Petal width (in cm)'].max(); v4=iris['Petal width (in cm)'].min(); 
r4=m4-v4;
print(r4); ## prints the range of Petal Width

## Range of SepalExtra
m5=iris['SepalExtra'].max(); v5=iris['SepalExtra'].min(); 
r5=m5-v5;
print(m5); ## prints the range of Petal Width
# Out:
# 2.4000000000000004
# 3.6000000000000005
# 5.9
# 2.4
# 30.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
asc=iris.sort_values(by=['Petal width (in cm)'])
print (asc); ## prints in ascending order of Petal Width

desc=iris.sort_values(by=['Petal width (in cm)'], ascending=False)
print (desc); ## prints in descending order of Petal Width
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 32                    5.2                  4.1                   1.5
# 9                     4.9                  3.1                   1.5
# 37                    4.9                  3.1                   1.5
# 34                    4.9                  3.1                   1.5
# 12                    4.8                  3.0                   1.4
# 13                    4.3                  3.0                   1.1
# 46                    5.1                  3.8                   1.6
# 42                    4.4                  3.2                   1.3
# 39                    5.1                  3.4                   1.5
# 38                    4.4                  3.0                   1.3
# 36                    5.5                  3.5                   1.3
# 33                    5.5                  4.2                   1.4
# 28                    5.2                  3.4                   1.4
# ...

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris=iris.drop(columns=['SepalExtra']); ## removes SepalExtra
print (iris);
# Out:
#      Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 109                   7.2                  3.6                   6.1
# 144                   6.7                  3.3                   5.7
# 100                   6.3                  3.3                   6.0
# 114                   5.8                  2.8                   5.1
# 140                   6.7                  3.1                   5.6
# 136                   6.3                  3.4                   5.6
# 148                   6.2                  3.4                   5.4
# 141                   6.9                  3.1                   5.1
# 120                   6.9                  3.2                   5.7
# 115                   6.4                  3.2                   5.3
# 145                   6.7                  3.0                   5.2
# 118                   7.7                  2.6                   6.9
# 135                   7.7                  3.0                   6.1
# ...

# %% [markdown]
# ### Print only the rows which has the class to be "Iris-setosa"

# %%
a=iris.loc[iris['Class']=='Iris-setosa']; 
print(a); ## prints rows having "Iris-setosa" as Class name
# Out:
#     Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 43                   5.0                  3.5                   1.6
# 23                   5.1                  3.3                   1.7
# 31                   5.4                  3.4                   1.5
# 44                   5.1                  3.8                   1.9
# 21                   5.1                  3.7                   1.5
# 5                    5.4                  3.9                   1.7
# 26                   5.0                  3.4                   1.6
# 16                   5.4                  3.9                   1.3
# 15                   5.7                  4.4                   1.5
# 19                   5.1                  3.8                   1.5
# 17                   5.1                  3.5                   1.4
# 6                    4.6                  3.4                   1.4
# 40                   5.0                  3.5                   1.3
# ...

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
iris=iris.sort_index(ascending=True)
IrisSubset=iris.iloc[:10, :3]; 
print (IrisSubset);
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
# 5                   5.4                  3.9                   1.7
# 6                   4.6                  3.4                   1.4
# 7                   5.0                  3.4                   1.5
# 8                   4.4                  2.9                   1.4
# 9                   4.9                  3.1                   1.5
