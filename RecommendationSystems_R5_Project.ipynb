# %%
# Building Recommendation systems to make product recommendations for Users of commerce systems

# %%
# Importing libraries for model building and computation

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 1) Read and understand the dataset
rat_ele= pd.read_csv("ratings_Electronics.csv", header=None)
rat_ele
# Out:
#                       0           1    2           3
# 0         AKM1MP6P0OYPR  0132793040  5.0  1365811200
# 1        A2CX7LUOHB2NDG  0321732944  5.0  1341100800
# 2        A2NWSAGRHCP8N5  0439886341  1.0  1367193600
# 3        A2WNBOD3WNDNKT  0439886341  3.0  1374451200
# 4        A1GI0U4ZRJA8WN  0439886341  1.0  1334707200
# 5        A1QGNMC6O1VW39  0511189877  5.0  1397433600
# 6        A3J3BRHTDRFJ2G  0511189877  2.0  1397433600
# 7        A2TY0BTJOTENPG  0511189877  5.0  1395878400
# 8        A34ATBPOK6HCHY  0511189877  5.0  1395532800
# 9         A89DO69P0XZ27  0511189877  5.0  1395446400
# 10        AZYNQZ94U6VDB  0511189877  5.0  1401321600
# 11       A1DA3W4GTFXP6O  0528881469  5.0  1405641600
# 12       A29LPQQDG7LD5J  0528881469  1.0  1352073600
# 13        AO94DHGC771SJ  0528881469  5.0  1370131200
# 14        AMO214LNFCEI4  0528881469  1.0  1290643200
# 15       A28B1G1MSJ6OO1  0528881469  4.0  1280016000
# 16       A3N7T0DY83Y4IG  0528881469  3.0  1283990400
# 17       A1H8PY3QHMQQA0  0528881469  2.0  1290556800
# 18        A2CPBQ5W4OGBX  0528881469  2.0  1277078400
# 19       A265MKAR2WEH3Y  0528881469  4.0  1294790400
# 20       A37K02NKUIT68K  0528881469  5.0  1293235200
# 21       A2AW1SSVUIYV9Y  0528881469  4.0  1289001600
# 22       A2AEHUKOV014BP  0528881469  5.0  1284249600
# 23        AMLFNXUIEMN4T  0528881469  1.0  1307836800
# 24       A2O8FIJR9EBU56  0528881469  4.0  1278547200
# 25       A3IQGFB959IR4P  0528881469  1.0  1327363200
# 26        AYTBGUX49LF3W  0528881469  4.0  1398470400
# 27       A24QFSUU00IZ05  0528881469  2.0  1293580800
# 28       A1NG5X8VYZWX0Q  0528881469  1.0  1286582400
# 29       A1E4WG8HRWWK4R  0528881469  5.0  1390867200
# ...                 ...         ...  ...         ...
# 7824452  A3AENU8Y9HLRAQ  B00LMOH8DU  5.0  1405209600
# 7824453   ABX8TXRB2GSKO  B00LMOH8DU  5.0  1405468800
# 7824454  A1QUWXCBPGCQMW  B00LMOH8DU  5.0  1405728000
# 7824455  A37B1XSZUYNSNK  B00LMOH8DU  5.0  1405036800
# 7824456  A3FOXB6244Y5PC  B00LNUH5X6  5.0  1404864000
# 7824457   AELQMX8YAEEYI  B00LOLBBQQ  5.0  1405382400
# 7824458   AG1NNE1V43RWC  B00LOLBBQQ  1.0  1405468800
# 7824459  A2QW4HHHC6XWH4  B00LPQRT34  4.0  1405209600
# 7824460  A2025SOZT6OE6D  B00LS5WBYE  5.0  1405641600
# 7824461  A2DOJYSPCLCQIT  B00LTAUTHE  5.0  1405382400
# 7824462  A1PB6OT0OOPKNQ  B00LXEC8CU  5.0  1405641600
# 7824463  A1MTPZKAYVSES3  BT008G3W52  5.0  1355702400
# 7824464   AS7WVL4JGN1FI  BT008SXQ4C  1.0  1326067200
# 7824465  A3GGII8ILEUI4P  BT008T2BGK  5.0  1320883200
# 7824466   ATK4Q037EM13F  BT008UKTMW  4.0  1356134400
# 7824467   AT10LK8R9MLHT  BT008UKTMW  3.0  1293753600
# 7824468   AKVMJCP7T93X1  BT008UKTMW  5.0  1394928000
# 7824469  A2H4BLBXDNSZ2O  BT008UKTMW  4.0  1316563200
# 7824470  A2DARIL2TWUOLS  BT008UKTMW  2.0  1373328000
# 7824471   A7ETK9SC1HAMP  BT008UKTMW  5.0  1397088000
# 7824472   A5FUA9HEV2O42  BT008UKTMW  5.0  1405987200
# 7824473   A84WRQR47OOKR  BT008UKTMW  1.0  1401753600
# 7824474  A180UGKKYCPDH0  BT008UKTMW  5.0  1369353600
# 7824475  A2R6Q6KJCYSVH7  BT008UKTMW  3.0  1343520000
# 7824476  A2IGIIABRZ5LAB  BT008UKTMW  5.0  1356739200
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW  5.0  1396569600
# 7824478  A322MDK0M89RHN  BT008UKTMW  5.0  1313366400
# 7824479  A1MH90R0ADMIK0  BT008UKTMW  4.0  1404172800
# 7824480  A10M2KEFPEQDHN  BT008UKTMW  4.0  1297555200
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U  5.0  1312675200
#
# [7824482 rows x 4 columns]

# %%
# Columns are UserID, ProductID, Rating, Timestamp in the same order
# Rename the columns with the column name for analysis

rat_ele.columns = ['UserID', 'ProductID', 'Rating', 'Timestamp']

# Timestamp is not required for analysis, hence can be removed from the dataset
rating = rat_ele.drop(columns=['Timestamp'])
rating
# Out:
#                  UserID   ProductID  Rating
# 0         AKM1MP6P0OYPR  0132793040     5.0
# 1        A2CX7LUOHB2NDG  0321732944     5.0
# 2        A2NWSAGRHCP8N5  0439886341     1.0
# 3        A2WNBOD3WNDNKT  0439886341     3.0
# 4        A1GI0U4ZRJA8WN  0439886341     1.0
# 5        A1QGNMC6O1VW39  0511189877     5.0
# 6        A3J3BRHTDRFJ2G  0511189877     2.0
# 7        A2TY0BTJOTENPG  0511189877     5.0
# 8        A34ATBPOK6HCHY  0511189877     5.0
# 9         A89DO69P0XZ27  0511189877     5.0
# 10        AZYNQZ94U6VDB  0511189877     5.0
# 11       A1DA3W4GTFXP6O  0528881469     5.0
# 12       A29LPQQDG7LD5J  0528881469     1.0
# 13        AO94DHGC771SJ  0528881469     5.0
# 14        AMO214LNFCEI4  0528881469     1.0
# 15       A28B1G1MSJ6OO1  0528881469     4.0
# 16       A3N7T0DY83Y4IG  0528881469     3.0
# 17       A1H8PY3QHMQQA0  0528881469     2.0
# 18        A2CPBQ5W4OGBX  0528881469     2.0
# 19       A265MKAR2WEH3Y  0528881469     4.0
# 20       A37K02NKUIT68K  0528881469     5.0
# 21       A2AW1SSVUIYV9Y  0528881469     4.0
# 22       A2AEHUKOV014BP  0528881469     5.0
# 23        AMLFNXUIEMN4T  0528881469     1.0
# 24       A2O8FIJR9EBU56  0528881469     4.0
# 25       A3IQGFB959IR4P  0528881469     1.0
# 26        AYTBGUX49LF3W  0528881469     4.0
# 27       A24QFSUU00IZ05  0528881469     2.0
# 28       A1NG5X8VYZWX0Q  0528881469     1.0
# 29       A1E4WG8HRWWK4R  0528881469     5.0
# ...                 ...         ...     ...
# 7824452  A3AENU8Y9HLRAQ  B00LMOH8DU     5.0
# 7824453   ABX8TXRB2GSKO  B00LMOH8DU     5.0
# 7824454  A1QUWXCBPGCQMW  B00LMOH8DU     5.0
# 7824455  A37B1XSZUYNSNK  B00LMOH8DU     5.0
# 7824456  A3FOXB6244Y5PC  B00LNUH5X6     5.0
# 7824457   AELQMX8YAEEYI  B00LOLBBQQ     5.0
# 7824458   AG1NNE1V43RWC  B00LOLBBQQ     1.0
# 7824459  A2QW4HHHC6XWH4  B00LPQRT34     4.0
# 7824460  A2025SOZT6OE6D  B00LS5WBYE     5.0
# 7824461  A2DOJYSPCLCQIT  B00LTAUTHE     5.0
# 7824462  A1PB6OT0OOPKNQ  B00LXEC8CU     5.0
# 7824463  A1MTPZKAYVSES3  BT008G3W52     5.0
# 7824464   AS7WVL4JGN1FI  BT008SXQ4C     1.0
# 7824465  A3GGII8ILEUI4P  BT008T2BGK     5.0
# 7824466   ATK4Q037EM13F  BT008UKTMW     4.0
# 7824467   AT10LK8R9MLHT  BT008UKTMW     3.0
# 7824468   AKVMJCP7T93X1  BT008UKTMW     5.0
# 7824469  A2H4BLBXDNSZ2O  BT008UKTMW     4.0
# 7824470  A2DARIL2TWUOLS  BT008UKTMW     2.0
# 7824471   A7ETK9SC1HAMP  BT008UKTMW     5.0
# 7824472   A5FUA9HEV2O42  BT008UKTMW     5.0
# 7824473   A84WRQR47OOKR  BT008UKTMW     1.0
# 7824474  A180UGKKYCPDH0  BT008UKTMW     5.0
# 7824475  A2R6Q6KJCYSVH7  BT008UKTMW     3.0
# 7824476  A2IGIIABRZ5LAB  BT008UKTMW     5.0
# 7824477  A2YZI3C9MOHC0L  BT008UKTMW     5.0
# 7824478  A322MDK0M89RHN  BT008UKTMW     5.0
# 7824479  A1MH90R0ADMIK0  BT008UKTMW     4.0
# 7824480  A10M2KEFPEQDHN  BT008UKTMW     4.0
# 7824481  A2G81TMIOIDEQQ  BT008V9J9U     5.0
#
# [7824482 rows x 3 columns]

# %%
# Data charactieristics

rating.info()

# UserID, ProductID belong to Object type
# Rating is of Numeric type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824482 entries, 0 to 7824481
# Data columns (total 3 columns):
# UserID       object
# ProductID    object
# Rating       float64
# dtypes: float64(1), object(2)
# memory usage: 179.1+ MB

# %%
# Let's check for missing values if any

rating[rating.isnull().any(axis=1)]

# No missing values in the dataset
# Out:
# Empty DataFrame
# Columns: [UserID, ProductID, Rating]
# Index: []

# %%
# Data Exploration

# Total number of distinct users, distint products and ratings

print("Total number of Unique Users is", len(rating['UserID'].unique()))
print("Total number of Unique Products is", len(rating['ProductID'].unique()))
print("Total number of Unique Ratings is", len(rating['Rating'].unique()))
# Out:
# Total number of Unique Users is 4201696
# Total number of Unique Products is 476002
# Total number of Unique Ratings is 5

# %%
# Top Ten Users who have given more ratings

a=rating['UserID'].value_counts()
a.head(10)
# Out:
# A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
# A1ODOGXEYECQQ8    380
# A36K2N527TXXJN    314
# A2AY4YUOX2N1BQ    311
# AWPODHOB4GFWL     308
# A25C2M3QF9G7OQ    296
# Name: UserID, dtype: int64

# %%
# Top Ten products that were rated by many users

p=rating['ProductID'].value_counts()
p.head(10)
# Out:
# B0074BW614    18244
# B00DR0PDNE    16454
# B007WTAJTO    14172
# B0019EHU8G    12285
# B006GWO5WK    12226
# B003ELYQGG    11617
# B003ES5ZUU    10276
# B007R5YDYA     9907
# B00622AG6S     9823
# B0002L5R78     9487
# Name: ProductID, dtype: int64

# %%
# Histogram of the rating variable

plt.hist(rating['Rating'])

# Rating 5 has been given many times followed by 4 and 1
# Out:
# (array([ 901765.,       0.,  456322.,       0.,       0.,  633073.,
#               0., 1485781.,       0., 4347541.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
# Understandng product vs count of each rating

#count_series = rating.groupby(['ProductID', 'Rating']).size()
#count_series

count_pro_rat = rating.groupby(['ProductID','Rating']).count().sort_values(by=['ProductID','Rating'],ascending=False)
count_pro_rat.columns=['Count']
count_pro_rat.T
# Out:
# ProductID BT008V9J9U BT008UKTMW                 BT008T2BGK BT008SXQ4C  \
# Rating           5.0        5.0 4.0 3.0 2.0 1.0        5.0        1.0
# Count              1          7   4   2   1   1          1          1
#
# ProductID BT008G3W52 B00LXEC8CU  ... 0528881469             0511189877      \
# Rating           5.0        5.0  ...        4.0 3.0 2.0 1.0        5.0 2.0
# Count              1          1  ...          5   1   5   9          5   1
#
# ProductID 0439886341     0321732944 0132793040
# Rating           3.0 1.0        5.0        5.0
# Count              1   2          1          1
#
# [1 rows x 1034832 columns]

# %%
# Understanding the user vs no of ratings he has given for each product

count_rat= rating.groupby(['UserID','Rating']).count().sort_values(by=['UserID','Rating'],ascending=False)
count_rat.columns=['Count']
count_rat.T
# Out:
# UserID AZZZY1W55XHZR AZZZWXXUPZ1F3 AZZZSIK7NFFVP AZZZRS1YZ8HVP AZZZOVIBXHGDR  \
# Rating           4.0           5.0           5.0           4.0           5.0
# Count              1             1             1             2             1
#
# UserID         AZZZMSZI9LKE6 AZZZM2FO19RUO AZZZJXM9GW3C5  ...  \
# Rating 4.0 1.0           4.0           4.0           5.0  ...
# Count    1   1             1             1             1  ...
#
# UserID A0001528BGUBOEVR6T5U A00015228CUPGPF957DS A00015222LZ55IJSVL5IX  \
# Rating                  3.0                  1.0                   1.0
# Count                     1                    1                     1
#
# UserID A000145014WOTZJ5NSKOR A00014061C2IZNE0YEILY A00010809P09NUU6ZP6H  \
# Rating                   5.0                   4.0                  5.0
# Count                      1                     1                    1
#
# UserID A00009661LC9LQPGKJ24G A00009182QVLSWIGHLS1B A000063614T1OE0BUSKUT  \
# Rating                   5.0                   5.0                   5.0
# Count                      1                     1                     2
#
# UserID A00000262KYZUE4J55XGL
# Rating                   5.0
# Count                      1
#
# [1 rows x 5407299 columns]

# %%
# 2) Making the data dense/ less sparse

# Identify users who have given ratings for atleast 50 products


s = rating['UserID'].value_counts()
idx = s[s>=50].index
rating_1=rating[rating['UserID'].isin(idx)]
rating_1

# Following gives the records of the Users who have rated for atleast 50 products
# Out:
#                  UserID   ProductID  Rating
# 94       A3BY5KCNQZXV5U  0594451647     5.0
# 118       AT09WGFUM934H  0594481813     3.0
# 177      A32HSNCNPRUMTR  0970407998     1.0
# 178      A17HMM1M7T9PJ1  0970407998     4.0
# 492      A3CLWR1UUZT6TG  0972683275     5.0
# 631      A3TAS1AG6FMBQW  0972683275     5.0
# 1003     A2Y4H3PXB07WQI  0972683275     4.0
# 1138     A25RTRAPQAJBDJ  0972683275     5.0
# 1310     A3LDPF5FMB782Z  1400501466     5.0
# 1322     A1A5KUIIIHFF4U  1400501466     1.0
# 1335     A2XIOXRRYX0KZY  1400501466     3.0
# 1451      AW3LX47IHPFRL  1400501466     5.0
# 1456     A1E3OB6QMBKRYZ  1400501466     1.0
# 1485     A19N3S7CBSU6O7  1400501466     5.0
# 1588     A3LDPF5FMB782Z  1400501520     5.0
# 1696     A3LDPF5FMB782Z  1400501776     5.0
# 1777     A18S2VGUH9SCV5  1400501776     4.0
# 1987     A1K4G5YJDJQI6Q  1400532620     1.0
# 1990     A1PPS91NLI7KEH  1400532620     5.0
# 2082     A2ZR3YTMEEIIZ4  1400532655     5.0
# 2150     A3CLWR1UUZT6TG  1400532655     5.0
# 2162      A5JLAU2ARJ0BO  1400532655     1.0
# 2228     A1P4XD7IORSEFN  1400532655     4.0
# 2363     A341HCMGNZCBIT  1400532655     5.0
# 2437     A3HPCRD9RX351S  1400532655     3.0
# 2502     A3LDPF5FMB782Z  140053271X     4.0
# 2741     A20UU20K7M9ZPF  140053271X     1.0
# 3007     A1DQHS7MOVYYYA  1400599997     5.0
# 3050      ALUNVOQRXOZIA  1400599997     1.0
# 3178     A19N3S7CBSU6O7  1400599997     5.0
# ...                 ...         ...     ...
# 7824171   A4WEZJOIZIV4U  B00L3YHF6O     5.0
# 7824191  A1EVV74UQYVKRY  B00L3YHF6O     5.0
# 7824192  A2XCCN239AR1XK  B00L3YHF6O     5.0
# 7824196  A1UQBFCERIP7VJ  B00L3YHF6O     5.0
# 7824198   AWPODHOB4GFWL  B00L3YHF6O     5.0
# 7824201  A35Q0RBM3YNQNF  B00L3YHF6O     5.0
# 7824208  A3R1WFO4KIUQXZ  B00L3YHF6O     5.0
# 7824209  A3S3R88HA0HZG3  B00L3YHF6O     5.0
# 7824212  A2XRMQA6PJ5ZJ8  B00L3YHF6O     5.0
# 7824216  A3A4ZAIBQWKOZS  B00L3YHF6O     5.0
# 7824221   AOVTLYTHVDNUX  B00L3YHF6O     5.0
# 7824241   AY6A8KPYCE6B0  B00L403O94     5.0
# 7824242   AVPNQUVZWMDSX  B00L43HAY6     5.0
# 7824285  A2HPJKM7L4EOQB  B00L5YZCCG     4.0
# 7824334  A2BLFCOPSMBOZ9  B00L8I6SFY     5.0
# 7824335  A3A4ZAIBQWKOZS  B00L8I6SFY     5.0
# 7824342    AA95DWUI3ODU  B00L8QCVL6     5.0
# 7824354  A2NYK9KWFMJV4Y  B00LA6T0LS     4.0
# 7824355  A3A4ZAIBQWKOZS  B00LA6T0LS     4.0
# 7824396  A3NHUQ33CFH3VM  B00LBZ1Z7K     3.0
# 7824414  A2XX2A4OJCDNLZ  B00LED02VY     4.0
# 7824422   AEIB3UR05OP7A  B00LGN7Y3G     5.0
# 7824423  A34BZM6S9L7QI4  B00LGQ6HL8     5.0
# 7824424  A1G650TTTHEAL5  B00LGQ6HL8     5.0
# 7824425  A25C2M3QF9G7OQ  B00LGQ6HL8     5.0
# 7824426   A1E1LEVQ9VQNK  B00LGQ6HL8     5.0
# 7824427  A2NYK9KWFMJV4Y  B00LGQ6HL8     5.0
# 7824436  A3AYSYSLHU26U9  B00LI4ZZO8     4.0
# 7824438  A2NYK9KWFMJV4Y  B00LI4ZZO8     5.0
# 7824444  A2BYV7S1QP2YIG  B00LKG1MC8     5.0
#
# [125871 rows x 3 columns]

# %%
# 3) Split the data into test and train sets for building models in the ratio of 7:3

from sklearn.model_selection import train_test_split
train_data, test_data = train_test_split(rating_1, test_size = 0.30, random_state=0)

print(train_data.shape)
print(test_data.shape)
# Out:
# (88109, 3)
# (37762, 3)

# %%
train_data
# Out:
#                  UserID   ProductID  Rating
# 6595853  A2BYV7S1QP2YIG  B009EAHVTA     5.0
# 4738241   AB094YABX21WQ  B0056XCEAA     1.0
# 4175596  A3D0UM4ZD2CMAW  B004I763AW     5.0
# 3753016   AATWFX0ZZSE6C  B0040NPHMO     3.0
# 1734767  A1NNMOD9H36Q8E  B0015VW3BM     4.0
# 256085   A3TA1UJWRJF9NC  B00008VFBE     5.0
# 3638199  A2PSC7LUNIDEAH  B003WOLM62     5.0
# 7492284  A3R4794K2RVU1S  B00E3VLB28     2.0
# 4799914  A1D9V11QUHXENQ  B005BCL66Y     4.0
# 4801788  A17V9XL4CWTQ6G  B005BHMDLQ     5.0
# 3022649  A178M2AHNWQZB0  B0032GV0XK     4.0
# 6032019  A3K91X9X2ARDOK  B00829TIEK     5.0
# 1624407  A2EZTM9WY5B5IL  B0012Y6HC8     5.0
# 7144340  A316XO4RWX21YN  B00BP54LEA     4.0
# 4466444  A3NG7X4APIV649  B004TKTOWC     4.0
# 3391704  A18GJ9MYYO6GCQ  B003J2V8AC     5.0
# 52202    A1O229NVVDJUX2  B00004TX71     4.0
# 5525053   ATMQEI1LKR6VB  B006ZH0JBM     5.0
# 6482857  A25C2M3QF9G7OQ  B0095P2F1S     4.0
# 1517624  A2D1ZQEFS1NBH2  B000XP8DJC     5.0
# 3075108  A11YIHB6IW352W  B0035LF2R2     5.0
# 1245256  A3QQGPI3CTV9SX  B000OE02G4     5.0
# 2305544  A2BLFCOPSMBOZ9  B001TH7GSW     5.0
# 4682819  A26BDXG9KVH7SU  B005450ZUG     3.0
# 3446097  A3BVN2QBNPBHCR  B003M0NURK     5.0
# 2442125  A12DQZKRKTNF5E  B002673Y7G     4.0
# 5366568  A2SH7OWE8QJYNC  B006DY3CRK     4.0
# 7423702  A3M7R4PD0FEPUB  B00DQZOD8Q     4.0
# 6431742  A2PB325LKXYDOL  B0090COZCS     5.0
# 5957818   A2SPV96SGOEO2  B007X3VEUW     3.0
# ...                 ...         ...     ...
# 6672982  A3MUSWDCTZINQZ  B009O7XUU2     4.0
# 5850253   AETQIN7OH0RL9  B007PQ11SC     4.0
# 5030148  A1DTCJV6KOMJOA  B005JW6WQU     5.0
# 7804411   ACJT8MUC0LRF0  B00IZGWTVO     5.0
# 6424567  A29KJ32G75L7G9  B00902SJY8     4.0
# 5570707   ADPKRJ2BSFJ0I  B0073FE1F0     5.0
# 7490575  A22CW0ZHY3NJH8  B00E3FJJYG     4.0
# 7001367  A2ZY49IDE6TY5I  B00B1HUIE4     4.0
# 1001600  A3AZI828WJN1CD  B000HGHMF8     5.0
# 1789119  A21S26XYPGXJZX  B0018C7FSO     3.0
# 890130   A2PY5ED630H0QJ  B000EW8074     1.0
# 4880781  A27ADCSD15F3GL  B005E8MVV4     5.0
# 2972110  A1USYP4AXF5I1D  B00305N48C     5.0
# 2205990  A24HWYHR28JJ7A  B001P11EGM     5.0
# 2747986  A30XZK10EZN9V4  B002OGMNT4     4.0
# 4930354   ABIVKBMSIPEDY  B005G81E9M     4.0
# 4895275  A3TPNC3TKGCCEI  B005EWB37S     5.0
# 7243568  A30X750M8V1XXW  B00CD8ADKO     4.0
# 3135486  A2V9DTXTQ5YIMK  B00387EW1K     5.0
# 5307638  A200DY76VXVGP9  B00650P2ZC     5.0
# 7751016  A2M14CFAMF8J7I  B00HGLOQ24     4.0
# 2351195  A3QDY9I0CNMD2W  B001UFYFYG     5.0
# 6153651   ACSX5AIZE3MJ9  B008BDBPTS     2.0
# 6040680  A1OMXVXXP07F05  B00832NCWU     2.0
# 1139768  A3S3R88HA0HZG3  B000LRMS66     5.0
# 2592347  A3QRW0UJPKIAX7  B002GYPS3M     1.0
# 7543940  A3AYSYSLHU26U9  B00EL8NIJC     5.0
# 2393178  A15T9G38F589KM  B001XUQP5A     5.0
# 2451900  A2QAOP52OEB5EV  B0026P45EE     5.0
# 4025040   ALDAF4VVLFRHP  B004CLYEH8     5.0
#
# [88109 rows x 3 columns]

# %%
# 4) Building Popular recommendation model using the Train data split

# Popularity, in our case, refers to the products that have a very good average rating by the customers
# In short, the better the average rating of the product, the better is the product

pop = train_data.groupby('ProductID')['Rating'].mean().sort_values(ascending=False).reset_index()
pop.head(100)

# Since Popularity based models are not unique or for giving customised recommendations to each user, the order of products will be the same for each user
# Out:
#      ProductID  Rating
# 0   0594451647     5.0
# 1   B004SBCF4Q     5.0
# 2   B000TUGSC0     5.0
# 3   B000TTMJ2E     5.0
# 4   B000TSZ51W     5.0
# 5   B004SBYQE8     5.0
# 6   B004SC4V3I     5.0
# 7   B000TSCL9Q     5.0
# 8   B000TSCL28     5.0
# 9   B004SCSV2U     5.0
# 10  B004SD1XB0     5.0
# 11  B000TQYZG0     5.0
# 12  B000TQVPJK     5.0
# 13  B004SDTAE2     5.0
# 14  B000TQVOLY     5.0
# 15  B000TO1SMG     5.0
# 16  B000TNZBFW     5.0
# 17  B004SBDIMO     5.0
# 18  B000TUMBMQ     5.0
# 19  B004SHBUM8     5.0
# 20  B004SBBDB2     5.0
# 21  B000TYN2PC     5.0
# 22  B004S6A1R4     5.0
# 23  B004S6QWDG     5.0
# 24  B004S76NH0     5.0
# 25  B004S7F2MW     5.0
# 26  B000TYHHGC     5.0
# 27  B004S7QKDC     5.0
# 28  B004S7W1RQ     5.0
# 29  B004S958VU     5.0
# ..         ...     ...
# 70  B000TGAWVM     5.0
# 71  B000TFQ5HI     5.0
# 72  B000TFNLAW     5.0
# 73  B004SR8ZTO     5.0
# 74  B004S6315S     5.0
# 75  B004S6084U     5.0
# 76  B004R4F2X0     5.0
# 77  B000UDBMZE     5.0
# 78  B000UD4O8Q     5.0
# 79  B004RCUUT8     5.0
# 80  B004RCWPQY     5.0
# 81  B004RDK8SA     5.0
# 82  B000UD3ODM     5.0
# 83  B004RE20M6     5.0
# 84  B000UD3LPI     5.0
# 85  B004RE5ZCI     5.0
# 86  B004RE8ZN4     5.0
# 87  B000UD205K     5.0
# 88  B004RFBIUU     5.0
# 89  B000UCELXK     5.0
# 90  B004RFGK30     5.0
# 91  B000UC5YSQ     5.0
# 92  B000UC22TK     5.0
# 93  B000UD6E48     5.0
# 94  B000UEWJ6O     5.0
# 95  B000UB7WD2     5.0
# 96  B000UF24OK     5.0
# 97  B004R6GELC     5.0
# 98  B004R6H2T0     5.0
# 99  B000UIA6YM     5.0
#
# [100 rows x 2 columns]

# %%
# 4) Building Popular recommendation model using the Test data split

# Popularity, in our case, refers to the products that have a very good average rating by the customers
# In short, the better the average rating of the product, the better is the product

pop1 = test_data.groupby('ProductID')['Rating'].mean().sort_values(ascending=False).reset_index()
pop1.head(100)

# Since Popularity based models are not unique or for giving customised recommendations to each user, the order of products will be the same for each user
# Out:
#      ProductID  Rating
# 0   B00LKG1MC8     5.0
# 1   B002U5MKLK     5.0
# 2   B002UUTCNE     5.0
# 3   B002UL0X1S     5.0
# 4   B002UKIFRI     5.0
# 5   B002UKDI84     5.0
# 6   B002UHKR6I     5.0
# 7   B002UHJ1II     5.0
# 8   B002UC4WZU     5.0
# 9   B002UBPBTC     5.0
# 10  B002UA2H9A     5.0
# 11  B002U84JAW     5.0
# 12  B002U6ZXX6     5.0
# 13  B002U5F56W     5.0
# 14  B002RTK0BQ     5.0
# 15  B002U1N95K     5.0
# 16  B002U0KE8Q     5.0
# 17  B002TZBW74     5.0
# 18  B002TYART4     5.0
# 19  B002TXJUJ8     5.0
# 20  B002TWTL2K     5.0
# 21  B002TWOGZ2     5.0
# 22  B002TWIYO6     5.0
# 23  B002TTITJY     5.0
# 24  B002TSZCIG     5.0
# 25  B002TQYSN8     5.0
# 26  B002UVNW5W     5.0
# 27  B002UXRED6     5.0
# 28  B002V07D0C     5.0
# 29  B002V0VKI8     5.0
# ..         ...     ...
# 70  B002SAJCYU     5.0
# 71  B002S7PS8M     5.0
# 72  B002S53IG8     5.0
# 73  B002S3Q87G     5.0
# 74  B002S0O7LI     5.0
# 75  B002RZQQTU     5.0
# 76  B002RZ3CBU     5.0
# 77  B002RWJHBM     5.0
# 78  B002RWJGTU     5.0
# 79  B002RWJGHC     5.0
# 80  B002SSK9VW     5.0
# 81  B002SSM5AU     5.0
# 82  B002TLTG9E     5.0
# 83  B002STGF6O     5.0
# 84  B002TLTE7I     5.0
# 85  B002TLT6U8     5.0
# 86  B002TLT07W     5.0
# 87  B002TLSW9O     5.0
# 88  B002TLD7H6     5.0
# 89  B002TKS0S8     5.0
# 90  B002TK2D04     5.0
# 91  B002TIELEM     5.0
# 92  B002TI71HQ     5.0
# 93  B002TG3AB4     5.0
# 94  B002TA7VO2     5.0
# 95  B002T6NQU4     5.0
# 96  B002T4XR78     5.0
# 97  B002SZDOM6     5.0
# 98  B002SYAQ50     5.0
# 99  B002SXMRW6     5.0
#
# [100 rows x 2 columns]

# %%
# Colaboratve Filtering

from surprise import Dataset,Reader

reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(rating_1[['UserID', 'ProductID', 'Rating']], reader)
data

# %%
# Split data to train and test in the Ratio of 7:3
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size=0.3,random_state=123)
type(trainset)
# Out:
# surprise.trainset.Trainset

# %%
# Training the Model

from surprise import KNNWithMeans
from surprise import accuracy
from surprise import Prediction

# %%
# Using Pearson similarity
algo = KNNWithMeans(sim_options={'name': 'pearson', 'user_based': False})
algo.fit(trainset)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
# Evalute on test set
test_pred = algo.test(testset)

# compute RMSE
accuracy.rmse(test_pred)
# Out:
# RMSE: 1.1321
# 1.1321360213199256

# %%
# using Cosine similarity
algo1= KNNWithMeans(sim_options={'name': 'cosine', 'user_based': False})
algo1.fit(trainset)
test_pred_1 = algo1.test(testset)
accuracy.rmse(test_pred_1)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.1432
# 1.1432072024725506

# %%
# Based on the similarity tests and RMSE observed, RMSE is better with Pearson than with Cosine similarity for the Item based collaborative filtering in this case

# %%
# Predicted result

test_pred
# Out:
# [Prediction(uid='A1SB9BNNGKNX2Z', iid='B00GK22DF2', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1J75JJ0Q2OEJN', iid='B000I992XY', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ACJT8MUC0LRF0', iid='B00CALICJI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A20DZX38KRBIT8', iid='B000JLKIHA', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ADLVFFE4VBT8', iid='B0007SKSES', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2RTVGR9B1M600', iid='B00GTYOMIW', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3SQCTNYQFVBWM', iid='B00EVWS1JK', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34VRVI4CSI5RQ', iid='B001FVLTNA', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2HKUM9OEBQKDW', iid='B000VX6XL6', r_ui=4.0, est=4.823529411764706, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3AG5QAT8L0I3R', iid='B00BWL33H8', r_ui=4.0, est=3.8947368421052633, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG35JCCQWDRCS', iid='B008JCVF0U', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3V7D0LH8L7BG0', iid='B000QSF2FY', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2LLSFQO8O8XNW', iid='B004065DAC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3QQGPI3CTV9SX', iid='B002OHDIWY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A32JCI4AK2JTTG', iid='B00025EKYA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3BACUOZV1M0WM', iid='B004JRYLG4', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AYOTEJ617O60K', iid='B00255GURK', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A35C2IVVQR1HTK', iid='B003Q9RERY', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AGJRUK27RBVYS', iid='B00171MWSO', r_ui=5.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3S5WYWYKSAI9C', iid='B00BIY7WNA', r_ui=3.0, est=3.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B0087B6SV4', r_ui=4.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A194Y47BF3CUTJ', iid='B004C4ZP82', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AGOH8N902URMW', iid='B0000511YT', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2WLNSZ9U0T1S3', iid='B00GY0UFFA', r_ui=5.0, est=4.384615384615385, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1LD5SE8IZ1H70', iid='B000G65R60', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A314KKDIJWCNMV', iid='B00011KM38', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A33SX0AD5PYD9B', iid='B005DOK8NW', r_ui=3.0, est=4.529411764705882, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1GBT4UN2RW7XY', iid='B0025ZH43O', r_ui=5.0, est=4.416666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A100WO06OQR8BQ', iid='B003MVZ60I', r_ui=5.0, est=2.725490196078431, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3D2VIUT2HWP0Z', iid='B001NTFATI', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NEAETOSXDBOM', iid='B007FPIQ0E', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SMD3T0QTN109', iid='B002IJ95ZM', r_ui=5.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2KOV8XWZOZ0FQ', iid='B0036RFGKS', r_ui=5.0, est=4.5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2F7CSE6KT7NI4', iid='B000V1MLBE', r_ui=5.0, est=3.9166666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3QNX5KWHDV0GD', iid='B008MB71IS', r_ui=4.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2UTZ4O5E2W4DK', iid='B003C2U05S', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AYP0YPLSP9ISM', iid='B003DOG6IK', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1E1LEVQ9VQNK', iid='B00DAR4ITE', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A105TOJ6LTVMBG', iid='B000LP0R3E', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1G650TTTHEAL5', iid='B00DSXG4YW', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A22S7D0LP8GRDH', iid='B0057CVH6W', r_ui=5.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1E55W6ES0FY17', iid='B002LITT3I', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1MRPX3RM48T2I', iid='B000HGIWN4', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AW68KVDV7BBRS', iid='B0050YG3CU', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AZCE11PSTCH1L', iid='B0039825LM', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B00CYYDDP4', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ASJLXOX1VD4DF', iid='B007ATHRJG', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3LGT6UZL99IW1', iid='B000SIFHZM', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1ZCSSCAGBCD49', iid='B002L6GEKG', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3LPL35P7FH78Y', iid='B004ASY5ZY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1NJHKPHD4YWZV', iid='B00064V6RG', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2PZXXPGLXXKZU', iid='B00E055H5O', r_ui=4.0, est=4.705882352941177, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A27GITTN6AVW5I', iid='B0087Y1XS4', r_ui=4.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3F7USIDJBR8WU', iid='B004J3V90Y', r_ui=1.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2EZTM9WY5B5IL', iid='B000OL22T2', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A203OCQQ12MAVT', iid='B00275XTSQ', r_ui=5.0, est=3.05, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AW5JSQCHC2ZJO', iid='B0097CZHAU', r_ui=4.0, est=4.315789473684211, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3N8O68DOEQ2FE', iid='B001V6RZO6', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2ZWJVKITA32OV', iid='B000P6BSEG', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3CW0ZLUO5X2B1', iid='B009SPNMZS', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1VQBEW0G4IH1J', iid='B004YHXXKO', r_ui=4.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3D0UM4ZD2CMAW', iid='B004ZCHV56', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2JE071UW97J2A', iid='B000GTBOR8', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AQ2FC1DLKVD8H', iid='B00E4RD4VC', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3CG93783LP0FO', iid='B003WVFAO0', r_ui=2.0, est=3.3333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1UCAVBNJUZMPR', iid='B00AHPSTJW', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3PJJTAKISAFI9', iid='B00004WCIC', r_ui=5.0, est=4.428571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1LD5SE8IZ1H70', iid='B004Q7IABO', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2YEZ8Z3BW2SKG', iid='B0078ZZ5NM', r_ui=3.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ALDAF4VVLFRHP', iid='B001ID829O', r_ui=5.0, est=4.833333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1UMSB7LAW0RIR', iid='B009AYVOG6', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3DOPYDOS49I3T', iid='B005DVJJWQ', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B001F7FMUA', r_ui=4.0, est=4.428571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AQNSQW4495SG0', iid='B00AI07F1Y', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2MJ8OL2FYN7CW', iid='B00DQZT38G', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AEJAGHLC675A7', iid='B00000DM9M', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1T9MILRRZ00F8', iid='B000ZJZ7OA', r_ui=4.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2D1ZQEFS1NBH2', iid='B00A2XKNO8', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SOJO7Z7R9WIA', iid='B00104XCVO', r_ui=4.0, est=4.571428571428571, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2BMZRO0H7TFCS', iid='B003KYTPTU', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A200DY76VXVGP9', iid='B0088PUEPK', r_ui=5.0, est=4.631578947368421, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AR3EVUQF0AC7R', iid='B002R5AM7C', r_ui=5.0, est=3.786476738905349, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A1F9Z42CFF9IAY', iid='B001V9KG0I', r_ui=5.0, est=4.714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A23QII83UGZP5U', iid='B000F2PHDI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AY3D7DG5L5WCK', iid='B0079UAT0A', r_ui=5.0, est=4.598727634955162, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2J8T58Z4X15IO', iid='B004XNLR16', r_ui=5.0, est=4.357142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3TAS1AG6FMBQW', iid='B00D8X9FSY', r_ui=5.0, est=4.339285714285714, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AUITG1DJ3QUGK', iid='B008BDBPTS', r_ui=3.0, est=3.1666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2UKE7GIVC7XFW', iid='B007VL8Y2C', r_ui=4.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A213J54E63SYOP', iid='B00456EC1I', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A36A1ZYZH8568P', iid='B005MTMFHU', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3D2VIUT2HWP0Z', iid='B001F7AHXM', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A33HIV8RXRDM88', iid='B003LSTD3S', r_ui=4.0, est=3.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3IJ4Z18FTIIP', iid='B009NB8WR0', r_ui=5.0, est=4.923076923076923, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A10ZFE6YE0UHW8', iid='B009SYZ8OC', r_ui=4.0, est=4.412191192266381, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AULFLNWJP1QXY', iid='B00064YNOY', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3ER6ARJ23CIN8', iid='B000068O5H', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A22S7D0LP8GRDH', iid='B001U02JZ8', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2W9GX82SLKROQ', iid='B00CP0I474', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1N5FSCYN4796F', iid='B006VJREFS', r_ui=3.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A10H24TDLK2VDP', iid='B000N99BBC', r_ui=5.0, est=4.516649048625793, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3Q1J68QY1MZQ9', iid='B00IZGWTVO', r_ui=2.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2L90SGUP36KGA', iid='B006X4ME0Q', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A11OTLEDSW8ZXD', iid='B004K1FTOC', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1QOIHVQC5XWCJ', iid='B003B3P29W', r_ui=4.0, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B003ES5ZUU', r_ui=5.0, est=4.66541822721598, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AQ3IN3MRXQ5KH', iid='B0058D8D94', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A27M75LRSJ788H', iid='B0073HSH8U', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AOMEH9W6LHC4S', iid='B00829TIEK', r_ui=5.0, est=4.833086720804151, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A7QMQBGJ2TCQG', iid='B00007EDZG', r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2SKEQT0WTB954', iid='B004X28I0A', r_ui=5.0, est=3.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2ARDVMUGDFED6', iid='B000IE8Z4Q', r_ui=4.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3QMJMTLJC34QC', iid='B005CLPP8E', r_ui=4.0, est=4.235294117647059, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ZTR0FR5AW9B4', iid='B000EVLS4C', r_ui=2.0, est=4.2, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ANRS196NKFVUU', iid='B000BQ7GW8', r_ui=5.0, est=4.782608695652174, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AK3GKIV8DEY8B', iid='B006QLIW1Q', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A4IL0CLL27Q33', iid='B00DIFIM36', r_ui=5.0, est=4.375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A370XYLIZCSK1Y', iid='B005QB2LDM', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A36K2N527TXXJN', iid='B002HJA4SU', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A28LUOEY0ECT9G', iid='B007STKINK', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1GW7V6S6XSXX3', iid='B009HQCARY', r_ui=5.0, est=2.6398809523809526, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3F9CMU8KNAY1M', iid='B001NTGSKI', r_ui=4.0, est=3.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35C2IVVQR1HTK', iid='B000V1MLBE', r_ui=1.0, est=3.9166666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3MMR2WDKAK0PA', iid='B001GNBD8I', r_ui=2.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2NVQZ4Y7Y0J1R', iid='B004TS2AOS', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9J4UURM4OSDW', iid='B000Z9UY2K', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A21I62TCDL4754', iid='B002PLBP56', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3N4VTNFPMTHEF', iid='B005TCMW7S', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3CP3J7OEGQMD5', iid='B002FFZGCU', r_ui=2.0, est=3.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A38RMU1Y5TDP9', iid='B00HEI1866', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A6VXZ1EEPRTLV', iid='B002UVU76E', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A6FIAB28IS79', iid='B00908BQCY', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A31N0XY2UTB25C', iid='B001PI9AAC', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ARW8VGT10JG60', iid='B0048IW030', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1QOIHVQC5XWCJ', iid='B000QEH0AS', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A100UD67AHFODS', iid='B00998P1JY', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2NJQF2UI60VGT', iid='B003VAK1I2', r_ui=5.0, est=4.111111111111111, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NOBH42C7UI5M', iid='B002DEM9HI', r_ui=4.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ARX0KOX5Q01BJ', iid='B007B5PQVA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A13WOT3RSXKRD5', iid='B00J4O1YBW', r_ui=2.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AZOK5STV85FBJ', iid='B0007OWNYA', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1CMD08Z49PGKQ', iid='B000652M6Y', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A11D1KHM7DVOQK', iid='B0002KH73Q', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AROQO2VDODT7', iid='B003G8EMA2', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AGATRDOFW48DK', iid='B000X3FAJU', r_ui=2.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A23GFTVIETX7DS', iid='B002VS4V0Y', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1A306IAZ3TM1', iid='B000LY4FLA', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1P0JSFW184ZXJ', iid='B000MQJ19S', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3FBM0RMCMAABV', iid='B00DUTIZJG', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A19XMHRB3G4DIR', iid='B00390JT1O', r_ui=5.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1PSVZBM894R5H', iid='B003D8GAA0', r_ui=5.0, est=2.3333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ZVFCPHCWFV71', iid='B0009OAFI4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3RGHO0Q938FRS', iid='B002JCSCYS', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3VTOLNB5N6FVP', iid='B003Y74AXO', r_ui=5.0, est=3.0833333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A15T9G38F589KM', iid='B004TS2AOS', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ASJLXOX1VD4DF', iid='B004YQX0SK', r_ui=4.0, est=3.8333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1VLVWTLV3LVHR', iid='B000CGIBAI', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2BX8DDQGCCG2J', iid='B006ITJHVA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A29GWIJL72GXXZ', iid='B0024I8H42', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A34JKODTSKCGEN', iid='B00CTY84KI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AJX9A4Q19UTJU', iid='B00A17IAOA', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2ALRZ0ENQLYY5', iid='B001TKE25E', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABH9D1TEOJ56E', iid='B000087BWL', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1EOTB1WHLSW6G', iid='B000094Q77', r_ui=5.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35IX2GE0VC0JP', iid='B004HKJTTC', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A20H1M28WLI9J2', iid='B001OC7IXU', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3S5WYWYKSAI9C', iid='B00ARB5FLQ', r_ui=4.0, est=3.5294117647058822, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1AWL9JASMG904', iid='B00D2CNS3O', r_ui=2.0, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A365PBEOWM7EI7', iid='B001TH7GUA', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A17BUUBOU0598B', iid='B009NE5YC8', r_ui=2.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9J4UURM4OSDW', iid='B000089GN2', r_ui=4.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1WXG10FJ353K0', iid='B002O0L0GC', r_ui=5.0, est=3.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3EZFFPVS34AMO', iid='B0042VSTZQ', r_ui=3.0, est=2.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABUE0ALHKWKHC', iid='B0032GU1LW', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2ZFFSJ0VM6KSJ', iid='B00F3F0EIU', r_ui=4.0, est=4.388888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1B8EJQU73YGL9', iid='B002WE0QN8', r_ui=5.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2NYOY6H42SORF', iid='B009ISU33E', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2OBDNQ5ZYU1L8', iid='B00F3F0EIU', r_ui=5.0, est=4.388888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1X3DA7C61WZLQ', iid='B004798MKA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ALHC64J88LVWO', iid='B004C53L1Y', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A6TBR6L2D4XKC', iid='B001F6TXME', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3MUSWDCTZINQZ', iid='B009T0NM0M', r_ui=4.0, est=3.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2KIJBT9HRIOM8', iid='B003ZW316U', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A5GPH59NDWJRB', iid='B00DQZO0R0', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AJCR7L4AXL2OG', iid='B000BP50AY', r_ui=1.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AONUCJBC85BL', iid='B002BH3I9U', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1U5IJHJK84S54', iid='B00BQ8RFAI', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3FBM0RMCMAABV', iid='B004T9RR6I', r_ui=4.0, est=4.375198238240046, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A1ZTR0FR5AW9B4', iid='B000XYDHY4', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A87CILADRIZW0', iid='B004XC6GJ0', r_ui=5.0, est=4.714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NHUQ33CFH3VM', iid='B002FCND0K', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2NB2E5DXE319Z', iid='B00IVPU6AA', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A376OJHLE6SU9Q', iid='B008X9Z44M', r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3NCIN6TNL0MGA', iid='B000EPLP3C', r_ui=2.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A680RUE1FDO8B', iid='B000EITTLE', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1WXG10FJ353K0', iid='B00CAY3WP4', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B005TDWV0K', r_ui=3.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1J75JJ0Q2OEJN', iid='B00E84H5DO', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B0020ZDI5C', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2WLNSZ9U0T1S3', iid='B005ARWDVW', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1VHCO8RQFIGQJ', iid='B0040JHVC2', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A376OJHLE6SU9Q', iid='B008X9ZBVI', r_ui=5.0, est=4.13511782900079, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A1G5MI2KREPEIB', iid='B0067I4Z6O', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A26KXNN6H1IL0I', iid='B00AVPWVH4', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1X1CEGHTHMBL1', iid='B000EY5F5C', r_ui=1.0, est=4.2727272727272725, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3QQGPI3CTV9SX', iid='B000RESRJU', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A35W3JQYP0M655', iid='B003ZUM5LE', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ARBKYIVNYWK3C', iid='B004SBBD8U', r_ui=5.0, est=4.88, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1F7YU6O5RU432', iid='B00D6JBZBK', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1SX9PHJWTDMF9', iid='B003LL51V8', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3HXGSMCIOZEW8', iid='B00746YHV6', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1V3TRGWOMA8LC', iid='B000023VUE', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1P3DDFL423B3C', iid='B0016P5ASK', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3TRY87JJCA5Y8', iid='B001AO4MWW', r_ui=5.0, est=2.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A6XDZ1MJ0B1A2', iid='B001AZUWXE', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A200RY2ELZL2Q3', iid='B00870VGGC', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1A535TCGNMVPI', iid='B00CM1BN5G', r_ui=4.0, est=2.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1V4A5U5O3TMMD', iid='B008Y5YO00', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3T7V207KRDE2O', iid='B008X9Z3UC', r_ui=5.0, est=4.416666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3VI2VETB90ZG5', iid='B00GGNDX1I', r_ui=4.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A376OJHLE6SU9Q', iid='B00007AKBA', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2M9ME0N2S3R39', iid='B0079G1TA8', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AQ2FC1DLKVD8H', iid='B0088CJT4U', r_ui=5.0, est=4.948665571951348, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A3LDPF5FMB782Z', iid='B002YIG8BQ', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1NRMTQ5SZPZA', iid='B009X2OS5Y', r_ui=4.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34C9AFFZOI45T', iid='B009IM6RWQ', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AN81JUYW2SL24', iid='B000VE4PNS', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34DQINHT6NYJU', iid='B00HSGFPC2', r_ui=5.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A19RW25Q6206I3', iid='B000WXD6JC', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A38C12950IM24P', iid='B00DK2JQOQ', r_ui=5.0, est=4.8, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B00829TIEK', r_ui=5.0, est=4.2280617183215154, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='A203OCQQ12MAVT', iid='B0013LQD7Y', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2QNS95WGN35G9', iid='B003FSTAVY', r_ui=5.0, est=3.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1VRANSQ0WF1YS', iid='B003YWDWD8', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3T8WOFS5RD2IR', iid='B0019X20R8', r_ui=2.0, est=4.363636363636363, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A28525P0S5ZVJ3', iid='B00006B9HO', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1C47ROOK7BSVL', iid='B008D6JDS8', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B0088PPFP4', r_ui=3.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A38KK0SZYEH5UD', iid='B0013A1XDY', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3HQAPXAJV7PRX', iid='B008DHS1K8', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ODOGXEYECQQ8', iid='B000V4TMEU', r_ui=4.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A31HE83MU98GBV', iid='B0029TZYFQ', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A11R5VW7IM6ISQ', iid='B000B5LQCA', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2DS9DLMSU2M2Z', iid='B00004WCEY', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35HUT8MQMT21L', iid='B001B0APOO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1V5TRJXTI6F01', iid='B005NGKR54', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2NYK9KWFMJV4Y', iid='B005GKYHJY', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1BXVZSQOJE6UE', iid='B004YIZW16', r_ui=4.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NEAETOSXDBOM', iid='B002FB684E', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1VHCO8RQFIGQJ', iid='B00B46XUQU', r_ui=3.0, est=4.043478260869565, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ACY9QYNDFLVBI', iid='B002FYL7PG', r_ui=4.0, est=4.125, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A267FU71Z01CIH', iid='B00G6CLN3Y', r_ui=4.0, est=3.0658914728682176, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2S26YGSVXBCFL', iid='B001FSIT9K', r_ui=4.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NHUQ33CFH3VM', iid='B00GLJGJTA', r_ui=5.0, est=3.3333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AC6Z7DP1Z5GHD', iid='B002CMLDT6', r_ui=4.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A194Y47BF3CUTJ', iid='B0002J2R2I', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2NJQF2UI60VGT', iid='B000QUUFRW', r_ui=5.0, est=4.891304347826087, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1TDR7Y90SVCHL', iid='B000MX48VM', r_ui=5.0, est=4.631578947368421, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3S5EXYZDEBF3K', iid='B008H9BXMK', r_ui=2.0, est=3.6956521739130435, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AT28RL25Q2OLK', iid='B004T1Y8SG', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3NOBH42C7UI5M', iid='B000XZCIX4', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1FLJCHN5CG5M5', iid='B003547GRI', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A145LBW8ZHF0TW', iid='B0058OSDLQ', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2LF07KCXDR70D', iid='B0009MX5R4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AVPNQUVZWMDSX', iid='B0029LB5D4', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A23ZXHFLC6TBLD', iid='B0026ZPFCK', r_ui=4.0, est=4.388888888888889, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AXU3VKZE848IY', iid='B005CT56F8', r_ui=2.0, est=4.837971788028974, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AT6CZDCP4TRGA', iid='B0000EWNWE', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A28J3123I1QDKI', iid='B0010CHHNA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AUCISQA1YXX86', iid='B001GIPSAW', r_ui=3.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A25UZ7MA72SMKM', iid='B005QCDY50', r_ui=5.0, est=4.159875038728215, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='A3JV071KO43Q5X', iid='B00748IJ2M', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A141OPVE376YFI', iid='B0062EUE54', r_ui=5.0, est=4.625, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B00GPKNCNG', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3A15L96IYUO6V', iid='B00004W3YK', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1143YEAZYMYHJ', iid='B000066JQU', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A31BD4RXCON7QO', iid='B0000AQFZ9', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2LW5AL0KQ9P1M', iid='B008ULPA2O', r_ui=4.0, est=4.244414289449933, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='A2X78O6G89CB30', iid='B0049HKKPK', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3FEGTOLCWXSV4', iid='B00DDK1QUC', r_ui=3.0, est=2.8154131763915196, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='A2UEB48LAWFUCW', iid='B003MAJMXQ', r_ui=5.0, est=4.285714285714286, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A5CDMTW6JKV5G', iid='B009YE461W', r_ui=5.0, est=3.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3J029KBNG5MNP', iid='B002C1BHIO', r_ui=5.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AQ55H30MZSV0Q', iid='B001IEVLWS', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ALDAF4VVLFRHP', iid='B004XVMX0C', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A21INUA35HX4XQ', iid='B0018Z0C9K', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AVJORH3ACR2A5', iid='B008MQQCG0', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3V2EZ6MA32FF6', iid='B00EI4V3FU', r_ui=5.0, est=2.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='APMYPD97EHUUZ', iid='B001FVI91U', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1EVV74UQYVKRY', iid='B005Z3GINK', r_ui=4.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B004I43F9C', r_ui=4.0, est=3.5714285714285716, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A24P4E3RJ6AX94', iid='B000S5Q9CA', r_ui=5.0, est=4.809523809523809, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3V6QSTG2T9MIO', iid='B00CZ0T5NG', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3RGJ1FXOB1ZLL', iid='B000OGX5AM', r_ui=5.0, est=4.933333333333334, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AKSQNMIKOU01H', iid='B000JLM50I', r_ui=4.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1PAGHECG401K1', iid='B00FA4Y7N2', r_ui=5.0, est=4.166666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9J4UURM4OSDW', iid='B00063ZVJQ', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3OXHLG6DIBRW8', iid='B00B8KWMKW', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3P69DTOXII004', iid='B00080FPRU', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3N4VTNFPMTHEF', iid='B000BNMWVG', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ARX7Z3NI6O0F7', iid='B0002E3WKE', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AQCJWSMSURQI2', iid='B00428N9M2', r_ui=3.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A6FIAB28IS79', iid='B0020ZDI5C', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2H4OMJLE7JFM2', iid='B0026322V4', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AV10H5K6VPQIJ', iid='B0027VT6V4', r_ui=5.0, est=4.214285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2YHXGPCTENZY3', iid='B004N7146U', r_ui=2.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2RGA7UGAN3UL7', iid='B001NJ0D0Y', r_ui=5.0, est=4.833333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2294LS59GC5K7', iid='B003GRH20A', r_ui=2.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3S5EXYZDEBF3K', iid='B004WOBCWU', r_ui=4.0, est=2.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3REK3OFONWB1Q', iid='B000AZ57M6', r_ui=4.0, est=4.8125, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3T8WOFS5RD2IR', iid='B001MQ332I', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1987V5OCO6QHS', iid='B003ZSHNGS', r_ui=4.0, est=4.875, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABIVKBMSIPEDY', iid='B0072DKWQ0', r_ui=4.0, est=4.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AV8MDYLHHTUOY', iid='B00IQ0SE22', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AR8LWDT6TUKNZ', iid='B00547IVXM', r_ui=5.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1ASWDAEDTTY5I', iid='B000MFG44Y', r_ui=2.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2OOXVZ6B1VZ9A', iid='B00387QY1Q', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1Z4GII5CHCDG7', iid='B001M56DI0', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1RDHBBZE1NPS3', iid='B001CBPWT0', r_ui=3.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3F8T3BRXRX5P3', iid='B00CO8T9VC', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2RN2AO4BE6F4K', iid='B004IZN3WU', r_ui=4.0, est=3.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1BVE2ZIBKJ7YI', iid='B00CFV45KS', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A51OFQVC6O5YL', iid='B008U12856', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1GW7V6S6XSXX3', iid='B002HWRK66', r_ui=2.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SL0HA6422W4M', iid='B0070U6N6I', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A10X9ME6R66JDX', iid='B0052SCU8U', r_ui=5.0, est=4.964285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AGEWOMQ90BV8R', iid='B003A4H2J0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2W9GX82SLKROQ', iid='B00A659HXK', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AAA0TUKS5VBSA', iid='B00006I53D', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3FEGTOLCWXSV4', iid='B00G6CLNCK', r_ui=4.0, est=2.9621489621489623, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2KYRPDKVBI2R4', iid='B001ZTZEH4', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2FHTXLKY1XJDB', iid='B006WBMXLK', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AWH2AY17ZU7W2', iid='B00CD1FB26', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A353U0L2HAMSHV', iid='B004GCJEZU', r_ui=4.0, est=4.130434782608695, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AL1XV4L25FZ2S', iid='B001QXDN5O', r_ui=4.0, est=3.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ASFP250F22MDZ', iid='B00FPKDPZC', r_ui=2.0, est=4.857142857142857, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AX7317G153T8W', iid='B008KEPX1O', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2E1EFNIZL2FVA', iid='B005VTGB0S', r_ui=4.0, est=3.375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A23GFTVIETX7DS', iid='B007MDQIH2', r_ui=3.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2JOPUWVV0XQJ3', iid='B00D02AG7C', r_ui=4.0, est=3.4285714285714284, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1MEISNED4NP7U', iid='B0029N3U8K', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9LNWA25IM2DX', iid='B0040XQ7PK', r_ui=3.0, est=3.205128205128205, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A4S2WAQVQR6PI', iid='B0051V31UO', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A18EA7MNLXP9H5', iid='B0001GAMQK', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AWZR0O65DL2Q', iid='B0000634T4', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SDJ70H00OQCJ', iid='B0029PQFT4', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A7EU2BWLLCJY2', iid='B008HU9R7W', r_ui=2.0, est=4.111111111111111, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3AVJCB1ZD6ZY5', iid='B002TLTGM6', r_ui=2.0, est=4.04, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1WG97A0EFHYXN', iid='B0040BPHJO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A213J54E63SYOP', iid='B0016OEV7C', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ALNE7Q71JFC0F', iid='B003OXOV1O', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1U5NWJOYH2QQH', iid='B0034KO59U', r_ui=1.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2H4OMJLE7JFM2', iid='B001ROVLWY', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
# ...
#  Prediction(uid='A1OO9N1MRNQ7K0', iid='B000BRO3PA', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3R4794K2RVU1S', iid='B002QUZM0U', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A18S2VGUH9SCV5', iid='B000YA4PPW', r_ui=5.0, est=2.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2PK64OVZA1U8Z', iid='B00F9ZQQ8Q', r_ui=3.0, est=3.4375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG6TX1ZJHLMO7', iid='B00HPM1G8Q', r_ui=4.0, est=4.497023809523809, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='AFHYEO3Y1IIDD', iid='B000LVN38Y', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2V1J3JT5OOZFO', iid='B002OD7Z36', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2ZFFSJ0VM6KSJ', iid='B000VY2BC0', r_ui=5.0, est=3.8181818181818183, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A16HXVNPU5TCGE', iid='B005PYZG6E', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3MMR2WDKAK0PA', iid='B000OLHGWK', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2R1HUYHXV7H18', iid='B00C9TECUO', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2V1J3JT5OOZFO', iid='B001V883UE', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A6FIAB28IS79', iid='B0073K64NM', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ASF3J4UYV34KA', iid='B007WTAJTO', r_ui=5.0, est=3.803174603174603, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='AD9ZL63H0VKCZ', iid='B004Y6DEAE', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1SHHQSPOWR00F', iid='B006P88VSE', r_ui=2.0, est=3.3333333333333335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AVBLGXSWRN666', iid='B00E6N9GS4', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AAEVGE52KL0DJ', iid='B0018PXRN8', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1ZPY91VE3IDN1', iid='B00CXADBRY', r_ui=5.0, est=4.247252747252747, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A38KK0SZYEH5UD', iid='B00BSREPRS', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A781ITP3HE2N5', iid='B000RZNI4S', r_ui=5.0, est=4.444444444444445, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3PPO2X5PJE1L9', iid='B003VS9UP4', r_ui=5.0, est=4.608695652173913, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2I2KPNJDQ9SL0', iid='B003ES5ZUU', r_ui=5.0, est=4.887640449438202, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AM0QLU79O05JR', iid='B00H4MJ1M0', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ATNOI7E8GTIVE', iid='B000TD8XES', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A25C2M3QF9G7OQ', iid='B0011NPHWQ', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2503LT8PZIHAD', iid='B001R4BTLC', r_ui=5.0, est=3.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1REY92IEZJUSX', iid='B0002E3WKO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3P69DTOXII004', iid='B00HIYA6PU', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AYP0YPLSP9ISM', iid='B00BEW8MVC', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2OBDNQ5ZYU1L8', iid='B000I3NUQ0', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1NJHKPHD4YWZV', iid='B0056XGGDQ', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A20L63B48RPSOH', iid='B0009PXGX4', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A11EYMH9UV9XG7', iid='B008C1JC4O', r_ui=5.0, est=4.642857142857143, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B000GFYTTW', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A33YZNZIRA3H97', iid='B00BOHNYTW', r_ui=5.0, est=4.714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A35X2JJI49OBZP', iid='B003WCAX28', r_ui=4.0, est=4.166666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG6TX1ZJHLMO7', iid='B0015VW3BM', r_ui=5.0, est=4.428571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2ZY3S7SD3QO8Z', iid='B009HQCAPQ', r_ui=3.0, est=3.3698412698412694, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A20G074MWH9U7O', iid='B0057LX9H8', r_ui=5.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SP7T2PZ3HSDE', iid='B001U3Y8O0', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A12DQZKRKTNF5E', iid='B00GBBT17K', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1Y4EWMUTW73GD', iid='B001E3ZNKY', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1ZCSSCAGBCD49', iid='B001IOY4Z4', r_ui=2.0, est=4.285714285714286, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A24HWYHR28JJ7A', iid='B006ZT4VA0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A370XYLIZCSK1Y', iid='B005UDITPK', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AVPNQUVZWMDSX', iid='B00C39KBVE', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A34CSXOGVYF94S', iid='B004CLYEH8', r_ui=5.0, est=4.54054054054054, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1WG97A0EFHYXN', iid='B0009B0KKA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A361U4SXK7FCQE', iid='B002FU5QMA', r_ui=5.0, est=4.714285714285714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2WB7LZ595CR50', iid='B002M78L6E', r_ui=3.0, est=4.163461538461538, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A3AG5QAT8L0I3R', iid='B000N99BBC', r_ui=4.0, est=4.784090909090909, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AIJQU979J6UFY', iid='B001KELVS0', r_ui=4.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A32HSNCNPRUMTR', iid='B007F9B0BW', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='ABAPF3XY1W6JX', iid='B0087NZ31S', r_ui=4.0, est=4.7, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A18HE80910BTZI', iid='B00E0EY7Z6', r_ui=5.0, est=3.533333333333333, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2TRXEZYU9GYY8', iid='B0055QYKQO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2GMZZ6TDYOHY7', iid='B003CK10DG', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AZCE11PSTCH1L', iid='B00D9UVQWO', r_ui=2.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2NX6MFZP8TM6S', iid='B000AYJDD6', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2UKE7GIVC7XFW', iid='B007RNCLBY', r_ui=4.0, est=4.131578947368421, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2JE071UW97J2A', iid='B0011NVMO8', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ALDAF4VVLFRHP', iid='B0053R0WWG', r_ui=5.0, est=4.6, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A9Y5O2R4D6EH5', iid='B005O88CUS', r_ui=3.0, est=3.4505494505494507, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2NX6PABLIJLP1', iid='B007R5YDYA', r_ui=5.0, est=4.7727272727272725, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ACJT8MUC0LRF0', iid='B003WCAX28', r_ui=5.0, est=4.166666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AULFLNWJP1QXY', iid='B004C13VWC', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3FPSY1M6G7XIB', iid='B00007E7JU', r_ui=5.0, est=4.428571428571429, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3SMD3T0QTN109', iid='B006W8U2MU', r_ui=5.0, est=4.84375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AKX9EQ37PAYMY', iid='B001T99ZTI', r_ui=5.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AIJQU979J6UFY', iid='B003WUBIZQ', r_ui=5.0, est=4.6923076923076925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A28LUOEY0ECT9G', iid='B0084JSJ98', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1W415JP5WEAJK', iid='B000P708NM', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AE88D7OM7YU99', iid='B006WAPM78', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A2TVH2OBNXYXHV', iid='B000UOAJR0', r_ui=2.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1T1YSCDW0PD25', iid='B00L2442H0', r_ui=5.0, est=4.833333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2XHOLOLKGV1FE', iid='B003S5SOLG', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A8FKL1DHTHC12', iid='B0062EUE54', r_ui=5.0, est=4.625, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG6TX1ZJHLMO7', iid='B0019DKOVW', r_ui=5.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AGATRDOFW48DK', iid='B00D5Q75RC', r_ui=5.0, est=4.923076923076923, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2JKM8KF3296CW', iid='B00EZ9XGGC', r_ui=3.0, est=4.25, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A274MXTX3DYLUV', iid='B004REA7MG', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3BNMHRW2R35LK', iid='B001NTDGQC', r_ui=3.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A20OBCQWBKCGZT', iid='B00KK9481I', r_ui=3.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1MNN0ZMHYPJDU', iid='B00BJNHGRM', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A3R4794K2RVU1S', iid='B001IOHAVO', r_ui=5.0, est=3.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1L5TA5UQF7EWE', iid='B0054MLMLA', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1VTCSCH8FFC76', iid='B00DB3SH2G', r_ui=5.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1FLJCHN5CG5M5', iid='B0077EAOSU', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A16C19G0I2DE8S', iid='B00AJWM6L0', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AXYM52DNK6NDF', iid='B00DQZRKY0', r_ui=2.0, est=4.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1EKSETIBS9ETQ', iid='B001U3Y8O0', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2MSBIA18RXYQC', iid='B0040IASMS', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='AGXV8E7XK9J6H', iid='B00119T6NQ', r_ui=4.0, est=3.9999999999999996, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2HDTOF8222KN3', iid='B00004T8R2', r_ui=5.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AWPODHOB4GFWL', iid='B00119T6NQ', r_ui=5.0, est=4.363636363636363, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1OMXVXXP07F05', iid='B00HF3X5RU', r_ui=3.0, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A22CW0ZHY3NJH8', iid='B006MVX5B2', r_ui=5.0, est=4.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2GKMXRLI7KLFP', iid='B002O3W2OI', r_ui=4.0, est=3.2666666666666666, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='ALHC64J88LVWO', iid='B005GINKRQ', r_ui=3.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1EXGL6L0QQ0M5', iid='B0000A12MH', r_ui=5.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A3Q6ZPW60CVF2L', iid='B005J5VLO0', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1KD8NJPZ01R37', iid='B000051SDT', r_ui=1.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A1N5FSCYN4796F', iid='B008PWUWLC', r_ui=2.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A25UZ7MA72SMKM', iid='B00CALM2KS', r_ui=5.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AOEDWQLH2WKKW', iid='B002CGSYLW', r_ui=4.0, est=4.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A1KKE6VX8VPWZK', iid='B00DDK1QUC', r_ui=5.0, est=3.75, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='A2NN1KIYEM2SKS', iid='B002GU5XKO', r_ui=5.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='AG8YP2XTC5X1I', iid='B00243HHNY', r_ui=4.0, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABIVKBMSIPEDY', iid='B000UEZ36W', r_ui=4.0, est=4.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2BLFCOPSMBOZ9', iid='B004CLYEDC', r_ui=5.0, est=4.646566569656772, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='A19FRW264WZTGP', iid='B00ACHMPCM', r_ui=1.0, est=2.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A2BMZRO0H7TFCS', iid='B0033160U2', r_ui=4.0, est=4.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='A370XYLIZCSK1Y', iid='B002Q0WN48', r_ui=4.0, est=4.2668149678239455, details={'was_impossible': True, 'reason': 'User and/or item is unkown.'}),
#  Prediction(uid='A145LBW8ZHF0TW', iid='B0035PBHX6', r_ui=5.0, est=1, details={'actual_k': 0, 'was_impossible': False}),
#  ...]

# %%
# Some of the results are having "was_impossible" set to False, the reason is because the User/Product details at the time of finding the similarity resulting in an Unknown value

# %%
# Top 5 Product Recommendations

test_new = trainset.build_anti_testset()
predictions = algo.test(test_new[0:100000])
predictions_df = pd.DataFrame([[x.uid,x.iid,x.est] for x in predictions])
predictions_df.columns = ["UserID","ProductID","Est_Rating"]
predictions_df.sort_values(by = ["UserID", "Est_Rating"],ascending=False,inplace=True)
top_5_recos = predictions_df.groupby("UserID").head(5).reset_index(drop=True)
top_5_recos

# Based on Item based similarity among Users, the Top 5 recommended products to each users are as listed below
# Out:
#             UserID   ProductID  Est_Rating
# 0    AHD3NZHDUZ5I6  B0046UJFAG         5.0
# 1    AHD3NZHDUZ5I6  B000EGQS5G         5.0
# 2    AHD3NZHDUZ5I6  B0012XAUS6         5.0
# 3    AHD3NZHDUZ5I6  B0007U0IRS         5.0
# 4    AHD3NZHDUZ5I6  B00DOJIZF6         5.0
# 5    AFR9GYKAHM37U  B0046UJFAG         5.0
# 6    AFR9GYKAHM37U  B00005105N         5.0
# 7    AFR9GYKAHM37U  B0012XAUS6         5.0
# 8    AFR9GYKAHM37U  B0007U0IRS         5.0
# 9    AFR9GYKAHM37U  B00DOJIZF6         5.0
# 10   AAQ9NJ480N9W5  B00005105N         5.0
# 11   AAQ9NJ480N9W5  B000EGQS5G         5.0
# 12   AAQ9NJ480N9W5  B0012XAUS6         5.0
# 13   AAQ9NJ480N9W5  B0007U0IRS         5.0
# 14   AAQ9NJ480N9W5  B00DOJIZF6         5.0
# 15  A20UU20K7M9ZPF  B0046UJFAG         5.0
# 16  A20UU20K7M9ZPF  B00005105N         5.0
# 17  A20UU20K7M9ZPF  B000EGQS5G         5.0
# 18  A20UU20K7M9ZPF  B0012XAUS6         5.0
# 19  A20UU20K7M9ZPF  B0007U0IRS         5.0

# %%
# Summary

# Given dataset has the ratings given by easch user to the product purchased in the range of 1-5
# In the Popularity based recommendation, since it's common to all without any personalisation, each user will be recommended with the products that got the highest avergae ratings among the total users
# Products with the highest average rating is derived for both the train and test set
# In the Collaborative based filtering, the problem is to identify similarity among users who have given the similar ratings to the products. In the event, similar users will be recommended with the other products that they did not purchase.
# While building the model, the RMSE for the model is computed with both Cosine and Pearson distance.
# In general, lower the RMSE, better the model is, because the standard deviation of the data points in the pursuit of best fit will be minimum if RMSE is lower
# Since Pearson distance gives the lower RMSE, the model works better with this than with Cosine.
# Using the same similarity technique, the recommended products for each User is identified and noted.
